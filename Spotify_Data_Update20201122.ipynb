# %%
import os
import requests
import json
from json import JSONEncoder
import pandas as pd
from datetime import datetime,timezone, timedelta
from tqdm import tqdm
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import base64
from urllib.parse import urlencode
import calendar
import pytz
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.util as util
import xlsxwriter
from tzlocal import get_localzone
import dateutil
import pandas_gbq
from google.oauth2 import service_account
import config

# %%
pd.options.mode.chained_assignment = None

# %%
def user_input():
    
    user_time_range = {"1":"short_term", "2":"medium_term", "3":"long_term"}

    time_range_reminder = ["1. short_term = approximately last 4 weeks", "2. medium_term = approximately last 6 months",
                          "3. long_term = calculated from several years of data and including all new data as it becomes available"]

    '''
    Ask user for specify time range
    - short_term = approximately last 4 weeks
    - medium_term = approximately last 6 months
    - long_term = calculated from several years of data and including all new data as it becomes available
    '''
    while True:
        print("How far back would you like to go?"
              "Select time range by typing the number 1-3, your choices: "
              "\n1. short_term = approximately last 4 weeks"
              "\n2. medium_term = approximately last 6 months"
              "\n3. long_term = calculated from several years of data and including all new data as it becomes available"
              "\nYour input: ")
        date_range = input("Time range #: ")
        i = 0

        while date_range not in user_time_range.keys():
            date_range = input("Invalid entry. Please select time range with number above: ")
            i += 1
            if i == 2:
                print("\nLooks like you're having trouble. Here are the available inputs: \n")
                print(time_range_reminder)
                print()
                date_range = input("Enter a court number: ")
                i += 1
            if i >= 3 and i % 3:
                quitting = input("Do you want to quit (yes/no)? ").lower()
                if quitting == "yes":
                    break
                else:
                    date_range = input("Select time range by typing the number 1-3, your choices: "
                              "\n1. short_term = approximately last 4 weeks"
                              "\n2. medium_term = approximately last 6 months"
                              "\n3. long_term = calculated from several years of data and including all new data as it becomes available"
                              "\nYour input: ")
            if court not in COURT_DATA_SEARCH.keys():
                quitting = "yes"
                return quitting
        return user_time_range[date_range]

# %%
get_filters1()
# Out:
# How far back would you like to go?Select time range by typing the number 1-3, your choices:
# 1. short_term = approximately last 4 weeks
# 2. medium_term = approximately last 6 months
# 3. long_term = calculated from several years of data and including all new data as it becomes available
# Your input:
# Time range #: 1
# 'short_term'

# %%
class Spotify_UserInput:
    user_time_range = {"1":"short_term", "2":"medium_term", "3":"long_term"}

    time_range_reminder = ["1. short_term = approximately last 4 weeks", "2. medium_term = approximately last 6 months",
                          "3. long_term = calculated from several years of data and including all new data as it becomes available"]
    
    def user_timerange(user_time_range, time_range_reminder):
        '''
        Ask user for specify time range
        - short_term = approximately last 4 weeks
        - medium_term = approximately last 6 months
        - long_term = calculated from several years of data and including all new data as it becomes available
        '''
        while True:
            print("How far back would you like to go?"
                  "\nSelect time range by typing the number 1-3, your choices: "
                  "\n1. short_term = approximately last 4 weeks"
                  "\n2. medium_term = approximately last 6 months"
                  "\n3. long_term = calculated from several years of data and including all new data as it becomes available"
                  "\nYour input: ")
            date_range = input("Time range #: ")
            i = 0

            while date_range not in user_time_range.keys():
                date_range = input("Invalid entry. Please select time range with number above: ")
                i += 1
                if i == 2:
                    print("\nLooks like you're having trouble. Here are the available inputs: \n")
                    print(time_range_reminder)
                    print()
                    date_range = input("Enter a court number: ")
                    i += 1
                if i >= 3 and i % 3:
                    quitting = input("Do you want to quit (yes/no)? ").lower()
                    if quitting == "yes":
                        break
                    else:
                        date_range = input("Select time range by typing the number 1-3, your choices: "
                                  "\n1. short_term = approximately last 4 weeks"
                                  "\n2. medium_term = approximately last 6 months"
                                  "\n3. long_term = calculated from several years of data and including all new data as it becomes available"
                                  "\nYour input: ")
                if court not in COURT_DATA_SEARCH.keys():
                    quitting = "yes"
                    return quitting
            print(f"Pulling '{user_time_range[date_range]}' data...")
            return user_time_range[date_range]

    
class Spotify_Auth:
    client_id = config.client_id
    client_secret = config.client_secret
    username = config.username
    
    def auth(client_id, client_secret, username):
        redirect_uri = 'http://localhost:7777/callback'
        scope = 'user-read-recently-played, user-top-read'

        auth_token = util.prompt_for_user_token(username=username, 
                                          scope=scope, 
                                          client_id=client_id,   
                                          client_secret=client_secret,     
                                          redirect_uri=redirect_uri)
        return auth_token

    
class Spotify_Data:
    
    def recently_played(auth_token):
        base_url = 'https://api.spotify.com/v1/me/player/recently-played?'
        #track_id = '6y0igZArWVi6Iz0rj35c1Y'

        #2. Authentication
        #3. Parameters -- would be stored with authentication
        headers = {
            "Authorization": f"Bearer {auth_token}"
        }

        #4. Create an empty list
        personal_data = [] #would be good explore how to capture data at different points in time
        r = requests.get(base_url+"&limit=50", headers=headers)
        personal_data.append(json.loads(r.text))
        
        return personal_data
    
    def top_tracks(auth_token, time_range):
        
        base_url = 'https://api.spotify.com/v1/me/top/tracks?'
        #track_id = '6y0igZArWVi6Iz0rj35c1Y'

        #2. Authentication
        #3. Parameters -- would be stored with authentication
        headers = {
            "Authorization": f"Bearer {auth_token}"
        }

        #4. Create an empty list
        top_track_data = [] #would be good explore how to capture data at different points in time
        r = requests.get(base_url+f"time_range={time_range}"+"&&limit=50", headers=headers)
        top_track_data.append(json.loads(r.text))
        
        return top_track_data
        

        
class Data_Clean:
    
    def recently_played_clean(personal_data):
        track_ids = []
        album_ids = []
        artist_ids = []
        album_names = []
        artist_names = []
        track_names = []
        popularity_ls = []
        played_ats = []

        for i in range(len(personal_data[0]['items'])):
            track_ids.append(personal_data[0]['items'][i]['track']['id']) # Track ID
            album_ids.append(personal_data[0]['items'][i]['track']['album']['id']) # Albumn ID
            artist_ids.append(personal_data[0]['items'][i]['track']['artists'][0]['id']) # Artist ID
            album_names.append(personal_data[0]['items'][i]['track']['album']['name']) # Album Name
            artist_names.append(personal_data[0]['items'][i]['track']['artists'][0]['name']) # Artist Name
            track_names.append(personal_data[0]['items'][i]['track']['name']) # Track Name
            popularity_ls.append(personal_data[0]['items'][i]['track']['popularity']) # Track Popularity
            played_ats.append(personal_data[0]['items'][i]['played_at'])

        list_dic={'track_id':track_ids,
              'album_id':album_ids,
              'artist_id':artist_ids,
              'track_name':track_names,
              'artist_name':artist_names,
              'album_name':album_names,
              'track_popularity':popularity_ls,
              'time_palyed': played_ats
        }

        df1=pd.DataFrame(list_dic)

        # Create empty column to append data to
        df1['local_time'] = ''

        for i in range(len(personal_data[0]['items'])):
            # Convert UTC to local time zone
            utc_time = dateutil.parser.parse(df1['time_palyed'].iloc[i]).astimezone(get_localzone())
            # Format date/time
            local_time= utc_time.strftime('%Y-%m-%d %H:%M:%S')
            local_time

            df1['local_time'].iloc[i] = local_time

        return df1
    
    def top_tracks_clean(top_track_data):
        track_idss = []
        album_idss = []
        artist_idss = []
        album_namess = []
        album_relase_datess = []
        artist_namess = []
        popularity_lss = []
        track_namess = []

        for i in range(len(top_track_data[0]['items'])):
            track_idss.append(top_track_data[0]['items'][i]['id']) # Track ID
            album_idss.append(top_track_data[0]['items'][i]['album']['id']) # Album ID
            artist_idss.append(top_track_data[0]['items'][i]['album']['artists'][0]['id'])
            album_namess.append(top_track_data[0]['items'][i]['album']['name']) # Album Name
            album_relase_datess.append(top_track_data[0]['items'][i]['album']['release_date'])
            artist_namess.append(top_track_data[0]['items'][i]['album']['artists'][0]['name']) # Artist Name
            popularity_lss.append(top_track_data[0]['items'][i]['popularity'])
            track_namess.append(top_track_data[0]['items'][i]['name']) # Track Name
            
        list_dic2 = {'track_id':track_idss,
           'album_id':album_idss,
           'artist_id':artist_idss,
           'track_name':track_namess,
           'album_name':album_namess,
           'artist_name':artist_namess,
           'track_popularity':popularity_lss,
           'album_relase_date':album_relase_datess,
                  }
        
        df2=pd.DataFrame(list_dic2)
        
        return df2

# %%
token = Spotify_Auth.auth(Spotify_Auth.client_id, Spotify_Auth.client_secret, Spotify_Auth.username)
token
# Out:
# 'BQBgeYBDmQHopWHUk95n23UVCMabbHSv1nixywgsa9o-hEHtTgwjBIbHXJExahgGJtkDJ8nqam_MdXtofOH7qAPAuO3pj09XUaYIlxTlHqLDByMx5qevvLIoGqmgA4FdK6PYFt8d0hlZco9SgAX9urI5JoXNITdhtJvW5U5rK9f_sTQllLcZHb_s8gsuJm_cE82-BeXzURe8uERCpMLCeNrkhmv6dcokI6rZ'

# %%
Data_Clean.recently_played_clean(Spotify_Data.recently_played(token))
# Out:
#                   track_id                album_id               artist_id  \
# 0   4FE9SgxcOoCNuGnaaU8TXz  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 1   6CCjbWdVB3BvHcSbjRaHwS  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 2   5exRDB26w6vi10fagGtgJS  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 3   7bUgWgmd1yTYu351xFBLDL  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 4   2g9LXMNIBCqmngHpH9nXv0  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 5   6m4p3NyVyVPTkyPj59UhZH  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 6   6YrnbbmCTE5423w3qBdxqA  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 7   5UQKkiYuxg0oe21ACerQ7u  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 8   6BqmgqzgKNxPszu1I6gOpn  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 9   6BqmgqzgKNxPszu1I6gOpn  2oiJM8vFGpxrtGtFfJWhJv  6ltzsmQQbmdoHHbLZ4ZN25
# 10  3GhsBdS9ulPK3KCdwHRPhG  6w9osZGOS8B7XWW51SBwFT  1QAJqy2dA3ihHBFIHRphZj
# 11  7LX4aXtvImhdgUHQBlo8Kp  5bP82ZIls6rzhpf5Qu6AzC  1QAJqy2dA3ihHBFIHRphZj
# 12  3AVrVz5rK8Hrqo9YGiVGN5  5bP82ZIls6rzhpf5Qu6AzC  1QAJqy2dA3ihHBFIHRphZj
# 13  6UFivO2zqqPFPoQYsEMuCc  4kkVGtCqE2NiAKosri9Rnd  3l0CmX0FuQjFxr8SK7Vqag
# 14  1Bh0UzthW8pKEnYg7v40Oa  6fUVptFdeOgcqDvCZzM2kC  1QAJqy2dA3ihHBFIHRphZj
# 15  3GhsBdS9ulPK3KCdwHRPhG  6w9osZGOS8B7XWW51SBwFT  1QAJqy2dA3ihHBFIHRphZj
# 16  7LX4aXtvImhdgUHQBlo8Kp  5bP82ZIls6rzhpf5Qu6AzC  1QAJqy2dA3ihHBFIHRphZj
# 17  3AVrVz5rK8Hrqo9YGiVGN5  5bP82ZIls6rzhpf5Qu6AzC  1QAJqy2dA3ihHBFIHRphZj
# 18  3y2Dktpll4t3zPlgpCnUCy  1D8cnABQfjvfQC2Cdk889m  6sHCvZe1PHrOAuYlwTLNH4
# 19  2EPuv7zyLpFqReJoYrIFzm  3U7jdirSqKYriJCSIucl10  2sSGPbdZJkaSE2AbcGOACx
# 20  0DuGEqN0pRJ5QAVFvnLe6P  1R5kPLo5rJAgp161g5hOFQ  35l9BRT7MXmM8bv2WDQiyB
# 21  7yyJF1BYBaCifNmO1RGhv7  6RIPvkeMrEPX4iY1H9ZiVc  3uwAm6vQy7kWPS2bciKWx9
r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#        'width': 64}],
#      'name': 'folklore',
#      'release_date': '2020-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LEiUm1SRbFMgfqnQTwUbQ'},
#       'href': 'https://api.spotify.com/v1/artists/4LEiUm1SRbFMgfqnQTwUbQ',
#       'id': '4LEiUm1SRbFMgfqnQTwUbQ',
#       'name': 'Bon Iver',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LEiUm1SRbFMgfqnQTwUbQ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 285634,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12002838'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4pvb0WLRcMtbPGmtejJJ6y'},
#     'href': 'https://api.spotify.com/v1/tracks/4pvb0WLRcMtbPGmtejJJ6y',
#     'id': '4pvb0WLRcMtbPGmtejJJ6y',
#     'is_local': False,
#     'name': 'exile (feat. Bon Iver)',
#     'popularity': 83,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b18c501a26b0df22304a662d9e36d1dcf9c046df?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:4pvb0WLRcMtbPGmtejJJ6y'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tFRohaO5yEsuJxmMnlCO9'},
#        'href': 'https://api.spotify.com/v1/artists/5tFRohaO5yEsuJxmMnlCO9',
#        'id': '5tFRohaO5yEsuJxmMnlCO9',
#        'name': 'Barns Courtney',
#        'type': 'artist',
#        'uri': 'spotify:artist:5tFRohaO5yEsuJxmMnlCO9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4XOMJHVuzJVWmqUdp4SYKP'},
#      'href': 'https://api.spotify.com/v1/albums/4XOMJHVuzJVWmqUdp4SYKP',
#      'id': '4XOMJHVuzJVWmqUdp4SYKP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c43ac981c6d7d1db6e6d633a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c43ac981c6d7d1db6e6d633a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c43ac981c6d7d1db6e6d633a',
#        'width': 64}],
#      'name': '404',
#      'release_date': '2019-09-06',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4XOMJHVuzJVWmqUdp4SYKP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tFRohaO5yEsuJxmMnlCO9'},
#       'href': 'https://api.spotify.com/v1/artists/5tFRohaO5yEsuJxmMnlCO9',
#       'id': '5tFRohaO5yEsuJxmMnlCO9',
#       'name': 'Barns Courtney',
#       'type': 'artist',
#       'uri': 'spotify:artist:5tFRohaO5yEsuJxmMnlCO9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 235773,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71900454'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4w2tfK0JA8KrVegKnxukf4'},
#     'href': 'https://api.spotify.com/v1/tracks/4w2tfK0JA8KrVegKnxukf4',
#     'id': '4w2tfK0JA8KrVegKnxukf4',
#     'is_local': False,
#     'name': 'The Kids Are Alright',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/616e966a2626f259c7460bf8e16ee7192f992eab?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:4w2tfK0JA8KrVegKnxukf4'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1QAJqy2dA3ihHBFIHRphZj'},
#        'href': 'https://api.spotify.com/v1/artists/1QAJqy2dA3ihHBFIHRphZj',
#        'id': '1QAJqy2dA3ihHBFIHRphZj',
#        'name': 'Cigarettes After Sex',
#        'type': 'artist',
#        'uri': 'spotify:artist:1QAJqy2dA3ihHBFIHRphZj'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5bP82ZIls6rzhpf5Qu6AzC'},
#      'href': 'https://api.spotify.com/v1/albums/5bP82ZIls6rzhpf5Qu6AzC',
#      'id': '5bP82ZIls6rzhpf5Qu6AzC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736b701428ed4c6e053902174a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026b701428ed4c6e053902174a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516b701428ed4c6e053902174a',
#        'width': 64}],
#      'name': 'Cigarettes After Sex',
#      'release_date': '2017-06-09',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5bP82ZIls6rzhpf5Qu6AzC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1QAJqy2dA3ihHBFIHRphZj'},
#       'href': 'https://api.spotify.com/v1/artists/1QAJqy2dA3ihHBFIHRphZj',
#       'id': '1QAJqy2dA3ihHBFIHRphZj',
#       'name': 'Cigarettes After Sex',
#       'type': 'artist',
#       'uri': 'spotify:artist:1QAJqy2dA3ihHBFIHRphZj'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 290146,
#     'explicit': False,
#     'external_ids': {'isrc': 'USBQU1700034'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3AVrVz5rK8Hrqo9YGiVGN5'},
#     'href': 'https://api.spotify.com/v1/tracks/3AVrVz5rK8Hrqo9YGiVGN5',
#     'id': '3AVrVz5rK8Hrqo9YGiVGN5',
#     'is_local': False,
#     'name': 'Apocalypse',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c896477c65a10edff588cb8a3123e59e200ed134?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3AVrVz5rK8Hrqo9YGiVGN5'},
#    {'album': {'album_type': 'SINGLE',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tFRohaO5yEsuJxmMnlCO9'},
#        'href': 'https://api.spotify.com/v1/artists/5tFRohaO5yEsuJxmMnlCO9',
#        'id': '5tFRohaO5yEsuJxmMnlCO9',
#        'name': 'Barns Courtney',
#        'type': 'artist',
#        'uri': 'spotify:artist:5tFRohaO5yEsuJxmMnlCO9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7c2VhL8HYMCwWIs54xEX2o'},
#      'href': 'https://api.spotify.com/v1/albums/7c2VhL8HYMCwWIs54xEX2o',
#      'id': '7c2VhL8HYMCwWIs54xEX2o',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f896bbe374af3dd6eeedde4d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f896bbe374af3dd6eeedde4d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f896bbe374af3dd6eeedde4d',
#        'width': 64}],
#      'name': 'Hard To Be Alone',
#      'release_date': '2020-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:7c2VhL8HYMCwWIs54xEX2o'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tFRohaO5yEsuJxmMnlCO9'},
#       'href': 'https://api.spotify.com/v1/artists/5tFRohaO5yEsuJxmMnlCO9',
#       'id': '5tFRohaO5yEsuJxmMnlCO9',
#       'name': 'Barns Courtney',
#       'type': 'artist',
#       'uri': 'spotify:artist:5tFRohaO5yEsuJxmMnlCO9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 182053,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM72002353'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6xQpOC55lufcqXvSzp7GTb'},
#     'href': 'https://api.spotify.com/v1/tracks/6xQpOC55lufcqXvSzp7GTb',
#     'id': '6xQpOC55lufcqXvSzp7GTb',
#     'is_local': False,
#     'name': 'Hard To Be Alone',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0bda4dcd5b63bcc0a2d237a25e1257e47f6e14a2?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6xQpOC55lufcqXvSzp7GTb'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#        'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#        'id': '26VFTg2z8YR0cCuwLzESi2',
#        'name': 'Halsey',
#        'type': 'artist',
#        'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/68enXe5XcJdciSDAZr0Alr'},
#      'href': 'https://api.spotify.com/v1/albums/68enXe5XcJdciSDAZr0Alr',
#      'id': '68enXe5XcJdciSDAZr0Alr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737636e1c9e67eaafc9f49aefd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027636e1c9e67eaafc9f49aefd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517636e1c9e67eaafc9f49aefd',
#        'width': 64}],
#      'name': 'Manic',
#      'release_date': '2020-01-17',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:68enXe5XcJdciSDAZr0Alr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#       'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#       'id': '26VFTg2z8YR0cCuwLzESi2',
#       'name': 'Halsey',
#       'type': 'artist',
#       'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 221095,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71918759'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/42SOtYBdnfj9zEdZSlAq5k'},
#     'href': 'https://api.spotify.com/v1/tracks/42SOtYBdnfj9zEdZSlAq5k',
#     'id': '42SOtYBdnfj9zEdZSlAq5k',
#     'is_local': False,
#     'name': 'Finally // beautiful stranger',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9a13d792165cee82c56706ae1aedc48470ed7697?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:42SOtYBdnfj9zEdZSlAq5k'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eJa3zG1QZLRB3xgRuyxbm'},
#        'href': 'https://api.spotify.com/v1/artists/6eJa3zG1QZLRB3xgRuyxbm',
#        'id': '6eJa3zG1QZLRB3xgRuyxbm',
#        'name': 'Dayglow',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eJa3zG1QZLRB3xgRuyxbm'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PFzbdbZRNaoGLCHFPnmv3'},
#      'href': 'https://api.spotify.com/v1/albums/5PFzbdbZRNaoGLCHFPnmv3',
#      'id': '5PFzbdbZRNaoGLCHFPnmv3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ccd63af052f7e438c05f6c94',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ccd63af052f7e438c05f6c94',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ccd63af052f7e438c05f6c94',
#        'width': 64}],
#      'name': 'Fuzzybrain',
#      'release_date': '2019-11-14',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:5PFzbdbZRNaoGLCHFPnmv3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eJa3zG1QZLRB3xgRuyxbm'},
#       'href': 'https://api.spotify.com/v1/artists/6eJa3zG1QZLRB3xgRuyxbm',
#       'id': '6eJa3zG1QZLRB3xgRuyxbm',
#       'name': 'Dayglow',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eJa3zG1QZLRB3xgRuyxbm'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 278769,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCADL1825079'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/64lsIF5pw0sJY0gV5kz0RN'},
#     'href': 'https://api.spotify.com/v1/tracks/64lsIF5pw0sJY0gV5kz0RN',
#     'id': '64lsIF5pw0sJY0gV5kz0RN',
#     'is_local': False,
#     'name': 'Can I Call You Tonight?',
#     'popularity': 82,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1df9f9b1d2fa409883d304d9fd3b8e45110e72fc?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:64lsIF5pw0sJY0gV5kz0RN'},
#    {'album': {'album_type': 'SINGLE',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YZ5ECfbM2xSTSQTJGBbO5'},
#        'href': 'https://api.spotify.com/v1/artists/4YZ5ECfbM2xSTSQTJGBbO5',
#        'id': '4YZ5ECfbM2xSTSQTJGBbO5',
#        'name': 'Gerard Way',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YZ5ECfbM2xSTSQTJGBbO5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6FiV1sKS2tKXj82g2iWEPv'},
#      'href': 'https://api.spotify.com/v1/albums/6FiV1sKS2tKXj82g2iWEPv',
#      'id': '6FiV1sKS2tKXj82g2iWEPv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732d55ec96ade31a8f79db7292',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022d55ec96ade31a8f79db7292',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512d55ec96ade31a8f79db7292',
#        'width': 64}],
#      'name': 'Here Comes the End (feat. Judith Hill)',
#      'release_date': '2020-07-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6FiV1sKS2tKXj82g2iWEPv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YZ5ECfbM2xSTSQTJGBbO5'},
#       'href': 'https://api.spotify.com/v1/artists/4YZ5ECfbM2xSTSQTJGBbO5',
#       'id': '4YZ5ECfbM2xSTSQTJGBbO5',
#       'name': 'Gerard Way',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YZ5ECfbM2xSTSQTJGBbO5'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/04ka9403wgTxmWFMY1PD5t'},
#       'href': 'https://api.spotify.com/v1/artists/04ka9403wgTxmWFMY1PD5t',
#       'id': '04ka9403wgTxmWFMY1PD5t',
#       'name': 'Judith Hill',
#       'type': 'artist',
#       'uri': 'spotify:artist:04ka9403wgTxmWFMY1PD5t'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 211633,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRE12000735'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0klnCzWGjoRQBjoPYe44Gl'},
#     'href': 'https://api.spotify.com/v1/tracks/0klnCzWGjoRQBjoPYe44Gl',
#     'id': '0klnCzWGjoRQBjoPYe44Gl',
#     'is_local': False,
#     'name': 'Here Comes the End (feat. Judith Hill)',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7df24c75636807e5f7c20b7cbede796027ae24a3?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0klnCzWGjoRQBjoPYe44Gl'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YZ5ECfbM2xSTSQTJGBbO5'},
#        'href': 'https://api.spotify.com/v1/artists/4YZ5ECfbM2xSTSQTJGBbO5',
#        'id': '4YZ5ECfbM2xSTSQTJGBbO5',
#        'name': 'Gerard Way',
#        'type': 'artist',
#        'uri': 'spotify:artist:4YZ5ECfbM2xSTSQTJGBbO5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6eIESGFbd6HVMqlO8e1mYT'},
#      'href': 'https://api.spotify.com/v1/albums/6eIESGFbd6HVMqlO8e1mYT',
#      'id': '6eIESGFbd6HVMqlO8e1mYT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b9125c789ff0729313be0ea2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b9125c789ff0729313be0ea2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b9125c789ff0729313be0ea2',
#        'width': 64}],
#      'name': 'Hesitant Alien',
#      'release_date': '2014-08-22',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:6eIESGFbd6HVMqlO8e1mYT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4YZ5ECfbM2xSTSQTJGBbO5'},
#       'href': 'https://api.spotify.com/v1/artists/4YZ5ECfbM2xSTSQTJGBbO5',
#       'id': '4YZ5ECfbM2xSTSQTJGBbO5',
#       'name': 'Gerard Way',
#       'type': 'artist',
#       'uri': 'spotify:artist:4YZ5ECfbM2xSTSQTJGBbO5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 270546,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRE11400474'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/31q2AsxMNpxHNENkWKG1j0'},
#     'href': 'https://api.spotify.com/v1/tracks/31q2AsxMNpxHNENkWKG1j0',
#     'id': '31q2AsxMNpxHNENkWKG1j0',
#     'is_local': False,
#     'name': 'Brother',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7af3aa2f16f479f5b1b61a84f89b9dcbba94da2c?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:31q2AsxMNpxHNENkWKG1j0'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#      'href': 'https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr',
#      'id': '2fenSS68JI1h4Fo296JfGr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#        'width': 64}],
#      'name': 'folklore',
#      'release_date': '2020-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 255893,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12002839'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1MgV7FIyNxIG7WzMRJV5HC'},
#     'href': 'https://api.spotify.com/v1/tracks/1MgV7FIyNxIG7WzMRJV5HC',
#     'id': '1MgV7FIyNxIG7WzMRJV5HC',
#     'is_local': False,
#     'name': 'my tears ricochet',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4a1d635bb0e0a185ee38de4a8b0ac4ff0b25b7e8?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:1MgV7FIyNxIG7WzMRJV5HC'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#      'href': 'https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr',
#      'id': '2fenSS68JI1h4Fo296JfGr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#        'width': 64}],
#      'name': 'folklore',
#      'release_date': '2020-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 210251,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUG12002835'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0Jlcvv8IykzHaSmj49uNW8'},
#     'href': 'https://api.spotify.com/v1/tracks/0Jlcvv8IykzHaSmj49uNW8',
#     'id': '0Jlcvv8IykzHaSmj49uNW8',
#     'is_local': False,
#     'name': 'the 1',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/efebd9d9b761b7685da9264c637a1db1cd994f19?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0Jlcvv8IykzHaSmj49uNW8'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr'},
#      'href': 'https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr',
#      'id': '2fenSS68JI1h4Fo296JfGr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc',
#        'width': 64}],
#      'name': 'folklore',
#      'release_date': '2020-07-24',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2fenSS68JI1h4Fo296JfGr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 208977,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG12002840'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ZNU020wNYvgW84iljPkPP'},
#     'href': 'https://api.spotify.com/v1/tracks/0ZNU020wNYvgW84iljPkPP',
#     'id': '0ZNU020wNYvgW84iljPkPP',
#     'is_local': False,
#     'name': 'mirrorball',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/38ae99baf0f13ee9298832ca8258769532e4bab5?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:0ZNU020wNYvgW84iljPkPP'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#        'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#        'id': '26VFTg2z8YR0cCuwLzESi2',
#        'name': 'Halsey',
#        'type': 'artist',
#        'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/68enXe5XcJdciSDAZr0Alr'},
#      'href': 'https://api.spotify.com/v1/albums/68enXe5XcJdciSDAZr0Alr',
#      'id': '68enXe5XcJdciSDAZr0Alr',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737636e1c9e67eaafc9f49aefd',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027636e1c9e67eaafc9f49aefd',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517636e1c9e67eaafc9f49aefd',
#        'width': 64}],
#      'name': 'Manic',
#      'release_date': '2020-01-17',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:68enXe5XcJdciSDAZr0Alr'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26VFTg2z8YR0cCuwLzESi2'},
#       'href': 'https://api.spotify.com/v1/artists/26VFTg2z8YR0cCuwLzESi2',
#       'id': '26VFTg2z8YR0cCuwLzESi2',
#       'name': 'Halsey',
#       'type': 'artist',
#       'uri': 'spotify:artist:26VFTg2z8YR0cCuwLzESi2'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 186187,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71918739'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/55ZcA6PazdlXjE1jO5GrzJ'},
#     'href': 'https://api.spotify.com/v1/tracks/55ZcA6PazdlXjE1jO5GrzJ',
#     'id': '55ZcA6PazdlXjE1jO5GrzJ',
#     'is_local': False,
#     'name': 'Ashley',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/30c946d7584703aa3fda8b078cb5b6df1b4aee90?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:55ZcA6PazdlXjE1jO5GrzJ'},
#    {'album': {'album_type': 'SINGLE',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3YQKmKGau1PzlVlkL1iodx'},
#        'href': 'https://api.spotify.com/v1/artists/3YQKmKGau1PzlVlkL1iodx',
#        'id': '3YQKmKGau1PzlVlkL1iodx',
#        'name': 'Twenty One Pilots',
#        'type': 'artist',
#        'uri': 'spotify:artist:3YQKmKGau1PzlVlkL1iodx'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
# ...
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2pWDyiJFya59ue0391kzSl'},
#      'href': 'https://api.spotify.com/v1/albums/2pWDyiJFya59ue0391kzSl',
#      'id': '2pWDyiJFya59ue0391kzSl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a9e5743f2d7c93c43fee849',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a9e5743f2d7c93c43fee849',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a9e5743f2d7c93c43fee849',
#        'width': 64}],
#      'name': 'The Attractions Of Youth',
#      'release_date': '2017-09-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2pWDyiJFya59ue0391kzSl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tFRohaO5yEsuJxmMnlCO9'},
#       'href': 'https://api.spotify.com/v1/artists/5tFRohaO5yEsuJxmMnlCO9',
#       'id': '5tFRohaO5yEsuJxmMnlCO9',
#       'name': 'Barns Courtney',
#       'type': 'artist',
#       'uri': 'spotify:artist:5tFRohaO5yEsuJxmMnlCO9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 197520,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71506495'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5w6B0sAH7XauCvMOAtplQj'},
#     'href': 'https://api.spotify.com/v1/tracks/5w6B0sAH7XauCvMOAtplQj',
#     'id': '5w6B0sAH7XauCvMOAtplQj',
#     'is_local': False,
#     'name': 'Fire',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/277dce635903763ad67a47f812120124c4d37453?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5w6B0sAH7XauCvMOAtplQj'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tFRohaO5yEsuJxmMnlCO9'},
#        'href': 'https://api.spotify.com/v1/artists/5tFRohaO5yEsuJxmMnlCO9',
#        'id': '5tFRohaO5yEsuJxmMnlCO9',
#        'name': 'Barns Courtney',
#        'type': 'artist',
#        'uri': 'spotify:artist:5tFRohaO5yEsuJxmMnlCO9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4XOMJHVuzJVWmqUdp4SYKP'},
#      'href': 'https://api.spotify.com/v1/albums/4XOMJHVuzJVWmqUdp4SYKP',
#      'id': '4XOMJHVuzJVWmqUdp4SYKP',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c43ac981c6d7d1db6e6d633a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c43ac981c6d7d1db6e6d633a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c43ac981c6d7d1db6e6d633a',
#        'width': 64}],
#      'name': '404',
#      'release_date': '2019-09-06',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4XOMJHVuzJVWmqUdp4SYKP'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5tFRohaO5yEsuJxmMnlCO9'},
#       'href': 'https://api.spotify.com/v1/artists/5tFRohaO5yEsuJxmMnlCO9',
#       'id': '5tFRohaO5yEsuJxmMnlCO9',
#       'name': 'Barns Courtney',
#       'type': 'artist',
#       'uri': 'spotify:artist:5tFRohaO5yEsuJxmMnlCO9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 176680,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71804597'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7krfJLNZ3Q1ITV3PKVbyoM'},
#     'href': 'https://api.spotify.com/v1/tracks/7krfJLNZ3Q1ITV3PKVbyoM',
#     'id': '7krfJLNZ3Q1ITV3PKVbyoM',
#     'is_local': False,
#     'name': 'You And I',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4e2e18a043bd5c5e8cc23115a86c84abed8efbf6?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7krfJLNZ3Q1ITV3PKVbyoM'},
#    {'album': {'album_type': 'SINGLE',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67WNUxmM7y4WzHPAVzBu3E'},
#        'href': 'https://api.spotify.com/v1/artists/67WNUxmM7y4WzHPAVzBu3E',
#        'id': '67WNUxmM7y4WzHPAVzBu3E',
#        'name': 'The Regrettes',
#        'type': 'artist',
#        'uri': 'spotify:artist:67WNUxmM7y4WzHPAVzBu3E'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/3BS7xxSYrwJm6XbRDAvmTJ'},
#        'href': 'https://api.spotify.com/v1/artists/3BS7xxSYrwJm6XbRDAvmTJ',
#        'id': '3BS7xxSYrwJm6XbRDAvmTJ',
#        'name': 'Dylan Minnette',
#        'type': 'artist',
#        'uri': 'spotify:artist:3BS7xxSYrwJm6XbRDAvmTJ'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/31i8FCqq0rEND2VDPzgkZY'},
#      'href': 'https://api.spotify.com/v1/albums/31i8FCqq0rEND2VDPzgkZY',
#      'id': '31i8FCqq0rEND2VDPzgkZY',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735cab72a623e4976b931316aa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025cab72a623e4976b931316aa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515cab72a623e4976b931316aa',
#        'width': 64}],
#      'name': 'Holiday-ish (feat. Dylan Minnette)',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:31i8FCqq0rEND2VDPzgkZY'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/67WNUxmM7y4WzHPAVzBu3E'},
#       'href': 'https://api.spotify.com/v1/artists/67WNUxmM7y4WzHPAVzBu3E',
#       'id': '67WNUxmM7y4WzHPAVzBu3E',
#       'name': 'The Regrettes',
#       'type': 'artist',
#       'uri': 'spotify:artist:67WNUxmM7y4WzHPAVzBu3E'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3BS7xxSYrwJm6XbRDAvmTJ'},
#       'href': 'https://api.spotify.com/v1/artists/3BS7xxSYrwJm6XbRDAvmTJ',
#       'id': '3BS7xxSYrwJm6XbRDAvmTJ',
#       'name': 'Dylan Minnette',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BS7xxSYrwJm6XbRDAvmTJ'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 198685,
#     'explicit': False,
#     'external_ids': {'isrc': 'USWB11902031'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3e3d7FRtLL43hvnqUeJAwq'},
#     'href': 'https://api.spotify.com/v1/tracks/3e3d7FRtLL43hvnqUeJAwq',
#     'id': '3e3d7FRtLL43hvnqUeJAwq',
#     'is_local': False,
#     'name': 'Holiday-ish (feat. Dylan Minnette)',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7b99f3e065f7708a99e4b21a976ba94f4f860561?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3e3d7FRtLL43hvnqUeJAwq'},
#    {'album': {'album_type': 'ALBUM',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4UXqAaa6dQYAk18Lv7PEgX'},
#        'href': 'https://api.spotify.com/v1/artists/4UXqAaa6dQYAk18Lv7PEgX',
#        'id': '4UXqAaa6dQYAk18Lv7PEgX',
#        'name': 'Fall Out Boy',
#        'type': 'artist',
#        'uri': 'spotify:artist:4UXqAaa6dQYAk18Lv7PEgX'}],
#      'available_markets': ['AD',
#       'AE',
#       'AR',
#       'AT',
#       'AU',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'SA',
#       'SE',
#       'SG',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'US',
#       'UY',
#       'VN',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Fd3LbDN1VzQj1BDb8gk4j'},
#      'href': 'https://api.spotify.com/v1/albums/2Fd3LbDN1VzQj1BDb8gk4j',
#      'id': '2Fd3LbDN1VzQj1BDb8gk4j',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f12c61574ec7c15d9b3d5c4b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f12c61574ec7c15d9b3d5c4b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f12c61574ec7c15d9b3d5c4b',
#        'width': 64}],
#      'name': 'Infinity On High',
#      'release_date': '2007-02-06',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2Fd3LbDN1VzQj1BDb8gk4j'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4UXqAaa6dQYAk18Lv7PEgX'},
#       'href': 'https://api.spotify.com/v1/artists/4UXqAaa6dQYAk18Lv7PEgX',
#       'id': '4UXqAaa6dQYAk18Lv7PEgX',
#       'name': 'Fall Out Boy',
#       'type': 'artist',
#       'uri': 'spotify:artist:4UXqAaa6dQYAk18Lv7PEgX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AR',
#      'AT',
#      'AU',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'SA',
#      'SE',
#      'SG',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'US',
#      'UY',
#      'VN',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 213586,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70700329'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4zCfMDdf5QXPKEqxdinXvB'},
#     'href': 'https://api.spotify.com/v1/tracks/4zCfMDdf5QXPKEqxdinXvB',
#     'id': '4zCfMDdf5QXPKEqxdinXvB',
#     'is_local': False,
#     'name': '"The Take Over, The Breaks Over"',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/57319bee155f4d50f8d6223ba2d7949cc97f8da6?cid=7b48c0d0afaf473fa001e013a4da575b',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4zCfMDdf5QXPKEqxdinXvB'}],
#   'total': 50,
#   'limit': 50,
#   'offset': 0,
#   'previous': None,
#   'href': 'https://api.spotify.com/v1/me/top/tracks?limit=50&offset=0',
#   'next': None}]

# %%
Data_Clean.top_tracks_clean(Spotify_Data.top_tracks(token, Spotify_UserInput.user_timerange(Spotify_UserInput.user_time_range, Spotify_UserInput.time_range_reminder)))
# Out:
# How far back would you like to go?
# Select time range by typing the number 1-3, your choices:
# 1. short_term = approximately last 4 weeks
# 2. medium_term = approximately last 6 months
# 3. long_term = calculated from several years of data and including all new data as it becomes available
# Your input:
# Time range #: 1
# Pulling 'short_term' data...
#                   track_id                album_id               artist_id  \
# 0   3AVrVz5rK8Hrqo9YGiVGN5  5bP82ZIls6rzhpf5Qu6AzC  1QAJqy2dA3ihHBFIHRphZj
# 1   7LX4aXtvImhdgUHQBlo8Kp  5bP82ZIls6rzhpf5Qu6AzC  1QAJqy2dA3ihHBFIHRphZj
# 2   7IY2JF7AlVN5uvIUBVnSJd  10fSu9RLAJlasIup4ylHPM  2eam0iDomRHGBypaDQLwWI
# 3   1gbgwb8AwRo9i42YaqWnj2  4Jkd7DR2cZjaVbQEQydXbX  2eam0iDomRHGBypaDQLwWI
# 4   3GhsBdS9ulPK3KCdwHRPhG  6w9osZGOS8B7XWW51SBwFT  1QAJqy2dA3ihHBFIHRphZj
# 5   4pvb0WLRcMtbPGmtejJJ6y  2fenSS68JI1h4Fo296JfGr  06HL4z0CvFAxyc27GXpf02
# 6   31q2AsxMNpxHNENkWKG1j0  6eIESGFbd6HVMqlO8e1mYT  4YZ5ECfbM2xSTSQTJGBbO5
# 7   1Bh0UzthW8pKEnYg7v40Oa  6fUVptFdeOgcqDvCZzM2kC  1QAJqy2dA3ihHBFIHRphZj
# 8   3VSYkAf6f46i5ZkXOHORq1  5bP82ZIls6rzhpf5Qu6AzC  1QAJqy2dA3ihHBFIHRphZj
# 9   3e3d7FRtLL43hvnqUeJAwq  31i8FCqq0rEND2VDPzgkZY  67WNUxmM7y4WzHPAVzBu3E
# 10  61EROL9kSJ5qhn1UH9mqc5  7F6XbqxHV4xIAj14oUCZoS  0Raaw7kr1Vzat4ZvHzjsJR
#
5bP82ZIls6rzhpf5Qu6AzC  1QAJqy2dA3ihHBFIHRphZj
# 42  4VeCmOb1rAEZQfH7Rlms9C  4cKEpUZp7REMrSjd4ICCZz  3gd8FJtBJtkRxdfbTu19U2
# 43  3A1kkAIXl4IPxeJRCCF4Bc  6fUVptFdeOgcqDvCZzM2kC  1QAJqy2dA3ihHBFIHRphZj
# 44  7dtGJHOBbVDwIWDQU38WhJ  6eIESGFbd6HVMqlO8e1mYT  4YZ5ECfbM2xSTSQTJGBbO5
# 45  1tBZnhDT8xbgJTs43FiqrD  4NBFFGWZqYd06XlBPEmgMX  4YZ5ECfbM2xSTSQTJGBbO5
# 46  04aAxqtGp5pv12UXAg4pkq  022DrG7Wp2PSCwzuD0bSzT  4UXqAaa6dQYAk18Lv7PEgX
# 47  2xfRDWDKOisEXgRnYI58Tb  6w9osZGOS8B7XWW51SBwFT  1QAJqy2dA3ihHBFIHRphZj
# 48  4LngVAmigX4WrBEDfonBlU  4cKEpUZp7REMrSjd4ICCZz  3gd8FJtBJtkRxdfbTu19U2
# 49  4XzBJwWmmvBP1I8y4sY4g4  4cKEpUZp7REMrSjd4ICCZz  3gd8FJtBJtkRxdfbTu19U2
#
#                                        track_name  \
# 0                                      Apocalypse
# 1                                              K.
# 2             chinatown (feat. Bruce Springsteen)
# 3                                              45
# 4                   Nothing's Gonna Hurt You Baby
# 5                          exile (feat. Bon Iver)
# 6                                         Brother
# 7                                        Heavenly
# 8                                           Sweet
# 9              Holiday-ish (feat. Dylan Minnette)
# 10                                 Christmas Drag
# 11                              Midnight in Paris
# 12                              An Air That Kills
# 13                     Dasher (feat. Lydia Night)
# 14                              You're All I Want
# 15  Must Stop (feat. Sarah Barthel of Phantogram)
# 16                                          Crush
# 17                                       Millions
# 18                        Can I Call You Tonight?
# 19                                        Sunsetz
# 20                      Merry Christmas Everybody
# 21                                Falling In Love
# 22         Here Comes the End (feat. Judith Hill)
# 23                                      Affection
# 24                                         Ashley
# 25                               Level of Concern
# 26                                  Every Holiday
# 27                                Don't Let Me Go
# 28                                        Hot Rod
# 29                  Finally // beautiful stranger
# 30                                Dreaming of You
# 31                     Each Time You Fall In Love
# 32                             Keep On Loving You
# 33                                      Neon Moon
# 34                              I'm A Firefighter
# 35                                 Kiss It Off Me
# 36                                     John Wayne
# 37                                   Sesame Syrup
# 38                                            Cry
# 39                                        Oh Noel
# 40                                             42
# 41                                          Flash
# 42                                  Guiding Light
# 43                                          Touch
# 44                                       No Shows
# 45          Hazy Shade of Winter (feat. Ray Toro)
# 46                                      Centuries
# 47                                    Starry Eyes
# 48                                          Woman
# 49                                        Beloved
#
#                                        album_name  \
# 0                            Cigarettes After Sex
# 1                            Cigarettes After Sex
# 2             chinatown (feat. Bruce Springsteen)
# 3                                              45
# 4                                              I.
# 5                                        folklore
# 6                                  Hesitant Alien
# 7                                             Cry
# 8                            Cigarettes After Sex
# 9              Holiday-ish (feat. Dylan Minnette)
# 10                                 Christmas Drag
# 11                      My First Failed Fairytale
# 12                  An Air That Kills / Possessed
# 13                     Dasher (feat. Lydia Night)
# 14                              You're All I Want
# 15  Must Stop (feat. Sarah Barthel of Phantogram)
# 16                                          Crush
# 17                                 Hesitant Alien
# 18                                     Fuzzybrain
# 19                           Cigarettes After Sex
# 20                                 Christmas Drag
